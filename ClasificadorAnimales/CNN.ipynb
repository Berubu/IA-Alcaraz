# %%
import cv2 

img = cv2.imread('dataset/gatos/0.jpg')
print(img.shape[0], img.shape[1], img.shape[2], len(img.shape))
# Out:
# 64 64 3 3

# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# # Importar Librerías

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import sys
print('sys.executable =', sys.executable)
print('Python version =', sys.version)
# Out:
# sys.executable = c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\env\Scripts\python.exe
# Python version = 3.12.2 (tags/v3.12.2:6abddd9, Feb  6 2024, 21:26:36) [MSC v.1937 64 bit (AMD64)]

# %%
import sys
import subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow"])
# Out:
# 0

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Added for Augmentation
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# # Cargar set de Imágenes

# %%
import sys
print('sys.executable =', sys.executable)
print('Python version =', sys.version)
# Out:
# sys.executable = c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\env\Scripts\python.exe
# Python version = 3.12.2 (tags/v3.12.2:6abddd9, Feb  6 2024, 21:26:36) [MSC v.1937 64 bit (AMD64)]

# %%
from skimage.transform import resize
dirname = os.path.join(os.getcwd(),'dataset')
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            # Fix: Handle RGBA images (4 channels) by keeping only RGB
            if image.shape[2] == 4:
                image = image[:, :, :3]
             #  Convertir en RGB si es en escala de grises
            if len(image.shape) == 2:
                image = np.stack((image,) * 3, axis=-1)

            #  Redimensionar a 32x32 para todas las imágenes
            image = resize(image, (64, 64), anti_aliasing=True, preserve_range=True)

            images.append(image.astype(np.uint8))
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# leyendo imagenes de  c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\Proyecto Unidad 22\dataset\
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\Proyecto Unidad 22\dataset\gatos 1
# Leyendo...15
# <>:15: SyntaxWarning: invalid escape sequence '\.'
# <>:15: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Adolfo\AppData\Local\Temp\ipykernel_4684\2598403112.py:15: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\Proyecto Unidad 22\dataset\hormigas 8000
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\Proyecto Unidad 22\dataset\mariquitas 7633
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\Proyecto Unidad 22\dataset\perros 8000
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\Proyecto Unidad 22\dataset\tortugas 8000
# Directorios leidos: 5
# Imagenes en cada directorio [8001, 7633, 8000, 8000, 7999]
# suma Total de imagenes en subdirs: 39633

# %% [markdown]
# # Creamos las etiquetas

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  39633

# %%
deportes=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    deportes.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 gatos
# 1 hormigas
# 2 mariquitas
# 3 perros
# 4 tortugas

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy



# Find the unique numbers from the train labels
classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# # Creamos Sets de Entrenamiento y Test

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (31706, 64, 64, 3) (31706,)
# Testing data shape :  (7927, 64, 64, 3) (7927,)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Display the first image in testing data
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 1')

# %% [markdown]
# # Preprocesamos las imagenes

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')

# 1. Preprocess FIRST (Scales to [-1, 1])
train_X = preprocess_input(train_X)
test_X = preprocess_input(test_X)

# 2. Visualize AFTER (Rescale [-1, 1] -> [0, 1] for display)
# If we don't do this, values are wrong for imshow and it looks white
plt.imshow((test_X[0] + 1) / 2)
plt.title("Visualización Correcta (Post-Procesamiento)")
# Out:
# Text(0.5, 1.0, 'Visualización Correcta (Post-Procesamiento)')

# %% [markdown]
# ## Hacemos el One-hot Encoding para la red

# %%
# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Display the change for category label using one-hot encoding
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 0
# After conversion to one-hot: [1. 0. 0. 0. 0.]

# %% [markdown]
# # Creamos el Set de Entrenamiento y Validación

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (25364, 64, 64, 3) (6342, 64, 64, 3) (25364, 5) (6342, 5)

# %% [markdown]
# # Creamos el modelo de CNN

# %%
#declaramos variables con los parámetros de configuración de la red
INIT_LR = 1e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 50 # Aumentado para mejor convergencia
batch_size = 32 # Reducido para mejor generalización

# %%
# Modelo CNN Profundo (4 Bloques) - Optimizado para Detalles Finos
# Arquitectura Secuencial 'Mini-VGG'

sport_model = Sequential()

# Bloque 1 (32 filtros) 
sport_model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(64, 64, 3)))
sport_model.add(BatchNormalization())
sport_model.add(MaxPooling2D(pool_size=(2, 2)))
sport_model.add(Dropout(0.25))

# Bloque 2 (64 filtros)
sport_model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
sport_model.add(BatchNormalization())
sport_model.add(MaxPooling2D(pool_size=(2, 2)))
sport_model.add(Dropout(0.25))

# Bloque 3 (128 filtros)
sport_model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
sport_model.add(BatchNormalization())
sport_model.add(MaxPooling2D(pool_size=(2, 2)))
sport_model.add(Dropout(0.4))

# Bloque 4 (256 filtros) - 
sport_model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
sport_model.add(BatchNormalization())
sport_model.add(MaxPooling2D(pool_size=(2, 2)))
sport_model.add(Dropout(0.4))

# Clasificación (Head Potente)
sport_model.add(Flatten())
sport_model.add(Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
sport_model.add(BatchNormalization())
sport_model.add(Dropout(0.5))
sport_model.add(Dense(nClasses, activation='softmax'))

sport_model.summary()
# Out:
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,441,477 (5.50 MB)
#  Trainable params: 1,440,005 (5.49 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %%
sport_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,441,477 (5.50 MB)
#  Trainable params: 1,440,005 (5.49 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %%
sport_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adam(learning_rate=INIT_LR), metrics=['accuracy'])

# %% [markdown]
# # Entrenamos el modelo: Aprende a clasificar imágenes

# %%
# Configurar Data Augmentation (Estándar - Alta Precisión)
# Revertido a la versión que funcionaba bien (sin deformación de color extrema)
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Callback para mejorar el aprendizaje si se estanca
from tensorflow.keras.callbacks import ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.00001, verbose=1)

print("Iniciando entrenamiento ESTÁNDAR (50 épocas + Augmentation Balanceado)...")
sport_train = sport_model.fit(
    datagen.flow(train_X, train_label, batch_size=batch_size),
    steps_per_epoch=len(train_X) // batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(valid_X, valid_label),
    callbacks=[reduce_lr]
)
# Out:
# Iniciando entrenamiento ESTÁNDAR (50 épocas + Augmentation Balanceado)...
# Epoch 1/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 134s 163ms/step - accuracy: 0.6268 - loss: 1.4315 - val_accuracy: 0.6670 - val_loss: 1.2531 - learning_rate: 0.0010
# Epoch 2/50
#   1/792 ━━━━━━━━━━━━━━━━━━━━ 1:46 135ms/step - accuracy: 0.5625 - loss: 1.4047
# c:\Users\Adolfo\Documents\ProyectsVisualStudioCode\Inteligencia Artificial\Entorno Virtual\env\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5625 - loss: 1.4047 - val_accuracy: 0.6511 - val_loss: 1.2999 - learning_rate: 0.0010
# Epoch 3/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 123s 155ms/step - accuracy: 0.7012 - loss: 1.0051 - val_accuracy: 0.7461 - val_loss: 0.8641 - learning_rate: 0.0010
# Epoch 4/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7500 - loss: 0.9080 - val_accuracy: 0.7512 - val_loss: 0.8595 - learning_rate: 0.0010
# Epoch 5/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 129s 163ms/step - accuracy: 0.7345 - loss: 0.8469 - val_accuracy: 0.7849 - val_loss: 0.7429 - learning_rate: 0.0010
# Epoch 6/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.6875 - loss: 1.1636 - val_accuracy: 0.7914 - val_loss: 0.7327 - learning_rate: 0.0010
# Epoch 7/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 117s 148ms/step - accuracy: 0.7532 - loss: 0.7952 - val_accuracy: 0.6870 - val_loss: 0.9846 - learning_rate: 0.0010
# Epoch 8/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8125 - loss: 0.6566 - val_accuracy: 0.7129 - val_loss: 0.9229 - learning_rate: 0.0010
# Epoch 9/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7624 - loss: 0.7828
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 129s 163ms/step - accuracy: 0.7631 - loss: 0.7822 - val_accuracy: 0.7465 - val_loss: 0.8747 - learning_rate: 0.0010
# Epoch 10/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8125 - loss: 0.6544 - val_accuracy: 0.7425 - val_loss: 0.8867 - learning_rate: 5.0000e-04
# Epoch 11/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 126s 159ms/step - accuracy: 0.7943 - loss: 0.6743 - val_accuracy: 0.8089 - val_loss: 0.6525 - learning_rate: 5.0000e-04
# Epoch 12/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8125 - loss: 0.7520 - val_accuracy: 0.8097 - val_loss: 0.6503 - learning_rate: 5.0000e-04
# Epoch 13/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 127s 160ms/step - accuracy: 0.8018 - loss: 0.6424 - val_accuracy: 0.7751 - val_loss: 0.7145 - learning_rate: 5.0000e-04
# Epoch 14/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8125 - loss: 0.5906 - val_accuracy: 0.7761 - val_loss: 0.7123 - learning_rate: 5.0000e-04
# Epoch 15/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 114s 144ms/step - accuracy: 0.8145 - loss: 0.6154 - val_accuracy: 0.8251 - val_loss: 0.5950 - learning_rate: 5.0000e-04
# Epoch 16/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7812 - loss: 0.6814 - val_accuracy: 0.8247 - val_loss: 0.5966 - learning_rate: 5.0000e-04
# Epoch 17/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 108s 136ms/step - accuracy: 0.8193 - loss: 0.6023 - val_accuracy: 0.8050 - val_loss: 0.6735 - learning_rate: 5.0000e-04
# Epoch 18/50
#   1/792 ━━━━━━━━━━━━━━━━━━━━ 2:19 176ms/step - accuracy: 0.9062 - loss: 0.5367
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9062 - loss: 0.5367 - val_accuracy: 0.7983 - val_loss: 0.6920 - learning_rate: 5.0000e-04
# Epoch 19/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 106s 134ms/step - accuracy: 0.8366 - loss: 0.5432 - val_accuracy: 0.7909 - val_loss: 0.6919 - learning_rate: 2.5000e-04
# Epoch 20/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9062 - loss: 0.4768 - val_accuracy: 0.7901 - val_loss: 0.6950 - learning_rate: 2.5000e-04
# Epoch 21/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 106s 134ms/step - accuracy: 0.8431 - loss: 0.5081 - val_accuracy: 0.8420 - val_loss: 0.5275 - learning_rate: 2.5000e-04
# Epoch 22/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9688 - loss: 0.3063 - val_accuracy: 0.8425 - val_loss: 0.5290 - learning_rate: 2.5000e-04
# Epoch 23/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 105s 133ms/step - accuracy: 0.8438 - loss: 0.4925 - val_accuracy: 0.8679 - val_loss: 0.4444 - learning_rate: 2.5000e-04
# Epoch 24/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9062 - loss: 0.3239 - val_accuracy: 0.8669 - val_loss: 0.4465 - learning_rate: 2.5000e-04
# Epoch 25/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 95s 120ms/step - accuracy: 0.8494 - loss: 0.4815 - val_accuracy: 0.8589 - val_loss: 0.4657 - learning_rate: 2.5000e-04
# Epoch 26/50
#   1/792 ━━━━━━━━━━━━━━━━━━━━ 1:12 92ms/step - accuracy: 0.8750 - loss: 0.3409
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8750 - loss: 0.3409 - val_accuracy: 0.8605 - val_loss: 0.4628 - learning_rate: 2.5000e-04
# Epoch 27/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 80s 101ms/step - accuracy: 0.8552 - loss: 0.4561 - val_accuracy: 0.8546 - val_loss: 0.4737 - learning_rate: 1.2500e-04
# Epoch 28/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9688 - loss: 0.2936 - val_accuracy: 0.8545 - val_loss: 0.4726 - learning_rate: 1.2500e-04
# Epoch 29/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 80s 101ms/step - accuracy: 0.8586 - loss: 0.4396 - val_accuracy: 0.8622 - val_loss: 0.4415 - learning_rate: 1.2500e-04
# Epoch 30/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9062 - loss: 0.4558 - val_accuracy: 0.8627 - val_loss: 0.4411 - learning_rate: 1.2500e-04
# Epoch 31/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 83s 104ms/step - accuracy: 0.8598 - loss: 0.4264 - val_accuracy: 0.8611 - val_loss: 0.4419 - learning_rate: 1.2500e-04
# Epoch 32/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8750 - loss: 0.4889 - val_accuracy: 0.8606 - val_loss: 0.4421 - learning_rate: 1.2500e-04
# Epoch 33/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 84s 105ms/step - accuracy: 0.8652 - loss: 0.4128 - val_accuracy: 0.8672 - val_loss: 0.4275 - learning_rate: 1.2500e-04
# Epoch 34/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9375 - loss: 0.3373 - val_accuracy: 0.8664 - val_loss: 0.4283 - learning_rate: 1.2500e-04
# Epoch 35/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 84s 106ms/step - accuracy: 0.8678 - loss: 0.4077 - val_accuracy: 0.8663 - val_loss: 0.4261 - learning_rate: 1.2500e-04
# Epoch 36/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8125 - loss: 0.5211 - val_accuracy: 0.8666 - val_loss: 0.4256 - learning_rate: 1.2500e-04
# Epoch 37/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 85s 107ms/step - accuracy: 0.8679 - loss: 0.4014 - val_accuracy: 0.8789 - val_loss: 0.3910 - learning_rate: 1.2500e-04
# Epoch 38/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9688 - loss: 0.2567 - val_accuracy: 0.8795 - val_loss: 0.3898 - learning_rate: 1.2500e-04
# Epoch 39/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 85s 108ms/step - accuracy: 0.8725 - loss: 0.3959 - val_accuracy: 0.8882 - val_loss: 0.3497 - learning_rate: 1.2500e-04
# Epoch 40/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8438 - loss: 0.4473 - val_accuracy: 0.8882 - val_loss: 0.3498 - learning_rate: 1.2500e-04
# Epoch 41/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 87s 110ms/step - accuracy: 0.8716 - loss: 0.3927 - val_accuracy: 0.8822 - val_loss: 0.3808 - learning_rate: 1.2500e-04
# Epoch 42/50
#   1/792 ━━━━━━━━━━━━━━━━━━━━ 1:20 102ms/step - accuracy: 0.8750 - loss: 0.4179
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8750 - loss: 0.4179 - val_accuracy: 0.8825 - val_loss: 0.3805 - learning_rate: 1.2500e-04
# Epoch 43/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.8722 - loss: 0.3848 - val_accuracy: 0.8877 - val_loss: 0.3594 - learning_rate: 6.2500e-05
# Epoch 44/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7812 - loss: 0.5223 - val_accuracy: 0.8884 - val_loss: 0.3590 - learning_rate: 6.2500e-05
# Epoch 45/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 87s 109ms/step - accuracy: 0.8773 - loss: 0.3745 - val_accuracy: 0.8936 - val_loss: 0.3362 - learning_rate: 6.2500e-05
# Epoch 46/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 0.1297 - val_accuracy: 0.8937 - val_loss: 0.3364 - learning_rate: 6.2500e-05
# Epoch 47/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 86s 109ms/step - accuracy: 0.8770 - loss: 0.3736 - val_accuracy: 0.8792 - val_loss: 0.3811 - learning_rate: 6.2500e-05
# Epoch 48/50
#   1/792 ━━━━━━━━━━━━━━━━━━━━ 1:19 101ms/step - accuracy: 1.0000 - loss: 0.2347
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 0.2347 - val_accuracy: 0.8783 - val_loss: 0.3815 - learning_rate: 6.2500e-05
# Epoch 49/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 87s 109ms/step - accuracy: 0.8780 - loss: 0.3625 - val_accuracy: 0.8917 - val_loss: 0.3512 - learning_rate: 3.1250e-05
# Epoch 50/50
# 792/792 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8125 - loss: 0.3778 - val_accuracy: 0.8920 - val_loss: 0.3510 - learning_rate: 3.1250e-05

# %%
# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
sport_model.save("animales_2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Evaluamos la red

# %%
test_eval = sport_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8799 - loss: 0.3639

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.36386504769325256
# Test accuracy: 0.8799041509628296

# %%
sport_train.history
# Out:
# {'accuracy': [0.6267961263656616,
#   0.5625,
#   0.7011684775352478,
#   0.75,
#   0.7345255017280579,
#   0.6875,
#   0.7531580328941345,
#   0.8125,
#   0.7631454467773438,
#   0.8125,
#   0.7943312525749207,
#   0.8125,
#   0.8018316626548767,
#   0.8125,
#   0.8145428895950317,
#   0.78125,
#   0.8193194270133972,
#   0.90625,
#   0.8366098403930664,
#   0.90625,
#   0.8431233167648315,
#   0.96875,
#   0.8437549471855164,
#   0.90625,
#   0.849399983882904,
#   0.875,
#   0.8552423715591431,
#   0.96875,
#   0.8585583567619324,
#   0.90625,
#   0.8598215579986572,
#   0.875,
#   0.8651902675628662,
#   0.9375,
#   0.8677956461906433,
#   0.8125,
#   0.867914080619812,
#   0.96875,
#   0.8724538087844849,
#   0.84375,
#   0.8715853691101074,
#   0.875,
#   0.8722169399261475,
#   0.78125,
#   0.877348780632019,
#   1.0,
#   0.877032995223999,
#   1.0,
#   0.8779804110527039,
#   0.8125],
#  'loss': [1.431528925895691,
#   1.404657006263733,
#   1.005092740058899,
#   0.9080306887626648,
#   0.8469493985176086,
#   1.163590669631958,
#   0.7951819896697998,
#   0.6565592885017395,
#   0.7821964025497437,
#   0.654392421245575,
#   0.674267053604126,
#   0.75196772813797,
#   0.6424206495285034,
#   0.5905683040618896,
#   0.6154254078865051,
#   0.6813839673995972,
#   0.6022595763206482,
#   0.5367146730422974,
#   0.5432081818580627,
#   0.4767875075340271,
#   0.5081180334091187,
#   0.3063291311264038,
#   0.4924760162830353,
#   0.32388049364089966,
#   0.48151397705078125,
#   0.34090423583984375,
#   0.4560776352882385,
#   0.2936350703239441,
#   0.4395706355571747,
#   0.45576590299606323,
#   0.4264005720615387,
#   0.48888057470321655,
#   0.4128330945968628,
#   0.33726760745048523,
#   0.40771791338920593,
#   0.5211054086685181,
#   0.4013586640357971,
#   0.2567024827003479,
#   0.39594975113868713,
#   0.44727227091789246,
#   0.39266571402549744,
#   0.4179365038871765,
#   0.3847879469394684,
#   0.5222859382629395,
#   0.3745311200618744,
#   0.1297127604484558,
#   0.3735840320587158,
#   0.2347441017627716,
#   0.3624810576438904,
#   0.37775227427482605],
#  'val_accuracy': [0.6669819951057434,
#   0.6510564684867859,
#   0.7461368441581726,
#   0.7511826157569885,
#   0.7849258780479431,
#   0.7913907170295715,
#   0.6870072484016418,
#   0.7128666043281555,
#   0.7464522123336792,
#   0.7425102591514587,
#   0.808893084526062,
#   0.8096814751625061,
#   0.7751498222351074,
#   0.7760958671569824,
#   0.8251340389251709,
#   0.8246610164642334,
#   0.8049511313438416,
#   0.7983285784721375,
#   0.790917694568634,
#   0.7901293039321899,
#   0.8420056700706482,
#   0.8424786925315857,
#   0.8678650259971619,
#   0.8669189810752869,
#   0.8588773012161255,
#   0.8604541420936584,
#   0.8546199798583984,
#   0.8544623255729675,
#   0.8621885776519775,
#   0.862661600112915,
#   0.8610848188400269,
#   0.8606117963790894,
#   0.8672342896461487,
#   0.8664458990097046,
#   0.8662882447242737,
#   0.8666036128997803,
#   0.8789025545120239,
#   0.8795332908630371,
#   0.8882055878639221,
#   0.8882055878639221,
#   0.882213830947876,
#   0.8825291991233826,
#   0.8877325654029846,
#   0.8883633017539978,
#   0.8935667276382446,
#   0.8937243819236755,
#   0.8792179226875305,
#   0.8782718181610107,
#   0.8916745781898499,
#   0.8919898867607117],
#  'val_loss': [1.2530878782272339,
#   1.2998621463775635,
#   0.8640907406806946,
#   0.8594807386398315,
#   0.74288409948349,
#   0.7326866388320923,
#   0.9846022725105286,
#   0.9229481816291809,
#   0.8747335076332092,
#   0.8866880536079407,
#   0.6525123119354248,
#   0.6502758264541626,
#   0.7144770622253418,
#   0.7123189568519592,
#   0.594983696937561,
#   0.5966395139694214,
#   0.6734948754310608,
#   0.6920251846313477,
#   0.6919271945953369,
#   0.6949722766876221,
#   0.5275206565856934,
#   0.5289642214775085,
#   0.44443318247795105,
#   0.44652676582336426,
#   0.465730220079422,
#   0.46284884214401245,
#   0.4737131893634796,
#   0.4725557267665863,
#   0.44149529933929443,
#   0.4411410093307495,
#   0.44187280535697937,
#   0.44205209612846375,
#   0.42747199535369873,
#   0.4283459484577179,
#   0.426105260848999,
#   0.4255586266517639,
#   0.39102765917778015,
#   0.38980138301849365,
#   0.3497195243835449,
#   0.34976258873939514,
#   0.38079017400741577,
#   0.3805035948753357,
#   0.35938262939453125,
#   0.35901474952697754,
#   0.33621951937675476,
#   0.3364211320877075,
#   0.38109850883483887,
#   0.3814743459224701,
#   0.35122254490852356,
#   0.35104936361312866],
#  'learning_rate': [0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0010000000474974513,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0005000000237487257,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0002500000118743628,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   0.0001250000059371814,
#   6.25000029685907e-05,
#   6.25000029685907e-05,
#   6.25000029685907e-05,
#   6.25000029685907e-05,
#   6.25000029685907e-05,
#   6.25000029685907e-05,
#   3.125000148429535e-05,
#   3.125000148429535e-05]}

# %%
accuracy = sport_train.history['accuracy']
val_accuracy = sport_train.history['val_accuracy']
loss = sport_train.history['loss']
val_loss = sport_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes2 = sport_model.predict(test_X)
# Out:
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step

# %%
predicted_classes=[]
for predicted_sport in predicted_classes2:
    predicted_classes.append(predicted_sport.tolist().index(max(predicted_sport)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((7927,), (7927,))

# %% [markdown]
# # Aprendamos de los errores: Qué mejorar

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow((test_X[correct] + 1) / 2, cmap='gray', interpolation='none')
    plt.title("{}, {}".format(deportes[predicted_classes[correct]],
                                                    deportes[test_Y[correct]]))

    plt.tight_layout()
# Out:
# Found 6975 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow((test_X[incorrect] + 1) / 2, cmap='gray', interpolation='none')
    plt.title("{}, {}".format(deportes[predicted_classes[incorrect]],
                                                    deportes[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 952 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.89      0.78      0.83      1666
#      Class 1       0.87      0.90      0.89      1558
#      Class 2       0.92      0.90      0.91      1543
#      Class 3       0.81      0.83      0.82      1592
#      Class 4       0.91      1.00      0.95      1568
#
#     accuracy                           0.88      7927
#    macro avg       0.88      0.88      0.88      7927
# weighted avg       0.88      0.88      0.88      7927

# %%
from skimage.transform import resize

images=[]
# AQUI ESPECIFICAMOS UNAS IMAGENES
filenames = ['tortuga 16.jpg',
'tortuga 17.jpg', 
'tortuga 18.jpg',
'tortuga 19.jpg'
]

for filepath in filenames:
    image = plt.imread(filepath,0)
    image_resized = resize(image, (64, 64),anti_aliasing=True,clip=False,preserve_range=True)
    images.append(image_resized)

X = np.array(images, dtype=np.uint8) #convierto de lista a numpy
test_X = X.astype('float32')
# test_X = test_X / 255.  
# Preprocess for MobileNetV2 (Scales to [-1, 1])
test_X = preprocess_input(test_X)

predicted_classes = sport_model.predict(test_X)

for i, img_tagged in enumerate(predicted_classes):
    print(filenames[i], deportes[img_tagged.tolist().index(max(img_tagged))])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# tortuga 16.jpg tortugas
# tortuga 17.jpg tortugas
# tortuga 18.jpg tortugas
# tortuga 19.jpg tortugas
